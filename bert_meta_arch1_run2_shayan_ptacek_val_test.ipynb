# %% [markdown]
# <a href="https://colab.research.google.com/github/nazmus007/arch1_shayan/blob/main/bert_meta_arch1_run2_shayan_ptacek_val_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -qq transformers
# Out:
#      |████████████████████████████████| 4.2 MB 8.4 MB/s
#      |████████████████████████████████| 86 kB 5.8 MB/s
#      |████████████████████████████████| 596 kB 58.2 MB/s
#      |████████████████████████████████| 6.6 MB 48.8 MB/s

# %%
print(transformers.__version__)
# Out:
# 4.10.0

# %%
# !pip install wandb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting wandb
#   Downloading wandb-0.12.17-py2.py3-none-any.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 8.1 MB/s
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from wandb) (6.0)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (7.1.2)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (5.4.8)
# Collecting setproctitle
#   Downloading setproctitle-1.2.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29 kB)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.5.12-py2.py3-none-any.whl (145 kB)
#      |████████████████████████████████| 145 kB 79.3 MB/s
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.9-py3-none-any.whl (9.4 kB)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.8.2)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.15.0)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.23.0)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.27-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 66.9 MB/s
# Requirement already satisfied: protobuf<4.0dev,>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.17.3)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from wandb) (57.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb) (4.2.0)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.6 MB/s
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2022.5.18.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (1.24.3)
# Building wheels for collected packages: pathtools
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=3f11c1fa2c072aa7603d2978f806b69204fa4bbdccb937055af09f9107562630
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built pathtools
# Installing collected packages: smmap, gitdb, shortuuid, setproctitle, sentry-sdk, pathtools, GitPython, docker-pycreds, wandb
# Successfully installed GitPython-3.1.27 docker-pycreds-0.4.0 gitdb-4.0.9 pathtools-0.1.2 sentry-sdk-1.5.12 setproctitle-1.2.3 shortuuid-1.0.9 smmap-5.0.0 wandb-0.12.17

# %%
# !wandb login
# Out:
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import transformers

from transformers import BertModel, BertTokenizer, AdamW, get_linear_schedule_with_warmup, BertForSequenceClassification

import torch
import re
import numpy as np
import pandas as pd

import seaborn as sns

from pylab import rcParams

import matplotlib.pyplot as plt

from matplotlib import rc

from sklearn.model_selection import train_test_split

from sklearn.metrics import confusion_matrix, classification_report

from collections import defaultdict

from textwrap import wrap

from torch import nn, optim

from torch.utils.data import Dataset, DataLoader

# %%
import torch.nn.functional as F

# %%
df_train = pd.read_csv("./drive/MyDrive/datasets/5datasets_combined_arch1_train.csv")

# %%
df_val = pd.read_csv("./drive/MyDrive/datasets/df_val_ptacek_cleaned.csv")

# %%
df_test = pd.read_csv("./drive/MyDrive/datasets/df_test_ptacek_cleaned.csv")

# %%
df_train = df_train.sort_values(by= "Label")

# %%
df_val = df_val.sort_values(by= "Label")

# %%
df_test = df_test.sort_values(by= "Label")

# %%
df_train = df_train[20000:102158]

# %%
df_val = df_val[9000:21198]

# %%
df_test= df_test[8000:]

# %%
import seaborn as sns
sns.countplot(df_val.Label)
plt.xlabel('Label');
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
emoji_1 = re.compile('[\\u203C-\\u3299\\U0001F000-\\U0001F644]')

# %%
emoji_list= list(filter(emoji_1.match, df_train['Tweet']))

# %%
print(emoji_list)
# Out:
# ['♥♥♥ rt  gif 131122 yixing heart to camera cr ', '【ml30】poland depth 10km nov 16 2013 121240 utc grin emsc', '♫ today prague czech republic  dec 31 at nye  cross club ', '♫ today prague czech republic  nov 18 at roxy ', '★ šok ★ hardwell priznal že ghostprodukoval 1 track z beatport top 10 ktorý to asi bude  s touto temnou ', '🎧my top 3 lastfm artists howard shore 14 dżem 8 andamp justin timberlake 7 ', '🌞gm☕️         followfriday', '♫ just downloaded new world sound andamp thomas newson  by     via ', '♫ today cottbus germany  nov 30 at blue moon festival ', '😂 rt   my uncle used to refer to missed calls as miskeen calls  laugh out loud', '🌞h ꭺꮲꮲꮍwꭼꭼꮶꭼꮑꭰ mꮍ fꮢꭵꭼꮑꭰs💕        ', '♥♥♥ rt  make sure to watch the special stage of exo 12월의기적miracles in december at kbs music bank ', '♫ mortal kombat theme  game theme – misterioustheme  nowplaying', '♫ just downloaded i am the melodyman hardcore edit by     via ', '😋 deli salat feldsalat jogurtsauce healty vegetarian whatvegetarianseat schnittlauch… ', '★ all my best wishes andamp happy new y34r 2014 keep partying andamp rave on  2013 was greatfull of goodiesand ', '♡  junbros  cras tagged charityevent samsungmedicalcentre ', '【europe】 2013126 231446 utc9  location 146km ne of praguecz  m31 tnt6736kg  depth 20km', '♩♬♪rain drops keep fallin on my head♩♪♬  galfa gmbh andamp co kg pic ', '🐉  your really chill but we do not talk anymore and i might possibly be your cheerleader 😳😛', '☕️good morning from germany🌞         happyday', '🎧my top 3 lastfm artists carnifex 11 blind ambitions 8 andamp hatebreed 3 lastfm ', '♡ me myself someoneelse mystyle jogger jogginghose kaputze ♡ ', '♫ today prague czech republic  nov 30 at transmission 10th anniversary ', '😕 looks like i am not goin to sleep shower there ', '★ soutěž o 3 kiss 2 volné vstupy na páteční ministry of sound cz party s moguaiem v duplex prague czech republic ★ ', '♫ just downloaded ellie goulding  you my everythi by     via ', '♫ just announced villach austria  jan 25 at vclub ', '😆“ i bet andy reid is looking at the waffle house menu”', '💕thanks salim my friend       happyfriday all my friends💕', '♫ today kladno czech republic  nov 30 at bpm club ', '💗bebe peludo 🐶🐶 puppy love lennon schnauzer happiness ', '♫ just announced thesau germany  dec 14 at club ', '▶ salesforce dataloader explained in 30 minute  youtube ', '♫ today prague czech republic  dec 12 at rc kain ', '🍃oh this will surely help the admissions office with their recruitment of students of color    ', '▶ guy kawasaki how to use social media as an evangelist for your business and here is how i did it youtube ', '♫ just downloaded laidback luke andamp peking duk  mufa by     via ', '♫ just downloaded above andamp beyond  sun andamp moon drop by     via ', '♫ just announced simbach germany  jan 18 at rezolut ', '♥  goodmorning hottests have a good day today ♥ ', '【europe】 2013126 231449 utc9  location 129km ne of praguecz  ml31 tnt6736kg  depth 100km', '😍😍 with theo in berlin 10112013 😘❤️  hurtsfamily hurts ', '♫ just announced velke pavlovice czech republic  jan 25 at millenium ', '🌏 the world is a book and those who do not travel read only a page 🌍', '♫ changing of the seasons – two door cinema club  nowplaying', '♫ just announced villach austria  jan 31 at vclub ', '【europe】 2013125 193439 utc9  location 91km nnw of wienat  ml27 tnt1692kg  depth 20km', '🍊🏈🍻you are so tall and really country i saw you at union city wal mart😂', '♫ just announced banbridge united kingdom  feb 8 at marc van gale pres digital collective 300 ', '👫🎈❤ love tagsforlikes tflers tweegram photooftheday 20likes amazing followme follow4follow… ', '♫ today ostrava czech republic  nov 23 at plan b hardcore cafe ', '🍀happy new year my friends🍀        ', '🍩goodmorning my friends☕️   ', '😍 rt  today i got a glimpse of heaven in the form of a light skin male with crystal blue eyes', '😏 i enjoy our random conversations at the bcm and i thank you for introducing me to one direction  godawgs', '🎧my top 3  ...

# %%
emo_found= ' '.join(emoji for emoji in emoji_list)

# %%
# !pip install demoji
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting demoji
#   Downloading demoji-1.1.0-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 1.6 MB/s
# Installing collected packages: demoji
# Successfully installed demoji-1.1.0

# %%
import demoji
def demoji_text(text):
  d= demoji.findall(text)
  return d

# %%
df_train['emoji_list'] = df_train['Tweet'].apply(demoji_text)

# %%
f= list(filter(None, df_train['emoji_list']))

# %%
print(f)
# Out:
# [{'😘': 'face blowing a kiss'}, {'😔': 'pensive face'}, {'☺': 'smiling face'}, {'😂': 'face with tears of joy'}, {'😿': 'crying cat', '😶': 'face without mouth'}, {'💕': 'two hearts'}, {'♥': 'heart suit'}, {'👌': 'OK hand'}, {'✋': 'raised hand'}, {'😍': 'smiling face with heart-eyes', '👌': 'OK hand'}, {'😩': 'weary face', '😭': 'loudly crying face'}, {'😉': 'winking face'}, {'❤️': 'red heart'}, {'💗': 'growing heart', '💕': 'two hearts'}, {'😂': 'face with tears of joy'}, {'♥': 'heart suit'}, {'👼': 'baby angel', '👙': 'bikini'}, {'🎶': 'musical notes'}, {'😊': 'smiling face with smiling eyes'}, {'🙊': 'speak-no-evil monkey', '😆': 'grinning squinting face', '🙈': 'see-no-evil monkey'}, {'😂': 'face with tears of joy'}, {'😒': 'unamused face', '✌️': 'victory hand'}, {'🐰': 'rabbit face', '🙊': 'speak-no-evil monkey', '💚': 'green heart'}, {'😘': 'face blowing a kiss'}, {'😳': 'flushed face'}, {'😉': 'winking face'}, {'👌': 'OK hand'}, {'😮': 'face with open mouth'}, {'☠': 'skull and crossbones'}, {'😀': 'grinning face'}, {'❤️': 'red heart'}, {'😒': 'unamused face'}, {'😱': 'face screaming in fear', '😳': 'flushed face'}, {'😒': 'unamused face'}, {'😄': 'grinning face with smiling eyes'}, {'😡': 'pouting face'}, {'💁': 'person tipping hand', '😘': 'face blowing a kiss', '😂': 'face with tears of joy'}, {'😑': 'expressionless face'}, {'❤': 'red heart', '😉': 'winking face'}, {'🙆': 'person gesturing OK'}, {'😍': 'smiling face with heart-eyes', '😐': 'neutral face'}, {'😒': 'unamused face'}, {'😡': 'pouting face'}, {'❤️': 'red heart'}, {'😳': 'flushed face'}, {'♥': 'heart suit'}, {'🎧': 'headphone'}, {'♥': 'heart suit'}, {'♥': 'heart suit'}, {'🎅': 'Santa Claus', '⛄': 'snowman without snow', '🎉': 'party popper', '🎄': 'Christmas tree'}, {'😁': 'beaming face with smiling eyes', '🌞': 'sun with face', '🌻': 'sunflower', '😘': 'face blowing a kiss', '💞': 'revolving hearts'}, {'♥️': 'heart suit'}, {'😑': 'expressionless face', '😡': 'pouting face'}, {'❗': 'red exclamation mark'}, {'😄': 'grinning face with smiling eyes'}, {'🙋': 'person raising hand'}, {'😠': 'angry face', '😒': 'unamused face', '😉': 'winking face'}, {'😒': 'unamused face'}, {'👍': 'thumbs up', '😶': 'face without mouth'}, {'❤️': 'red heart', '❄️': 'snowflake', '🎅': 'Santa Claus', '🎄': 'Christmas tree', '💜': 'purple heart'}, {'❤': 'red heart', '😉': 'winking face'}, {'🔫': 'water pistol'}, {'🌞': 'sun with face', '☕': 'hot beverage'}, {'😂': 'face with tears of joy'}, {'♥': 'heart suit'}, {'😡': 'pouting face'}, {'😒': 'unamused face'}, {'👌': 'OK hand', '👍': 'thumbs up'}, {'👊': 'oncoming fist'}, {'®': 'registered'}, {'💖': 'sparkling heart'}, {'🙈': 'see-no-evil monkey'}, {'❤': 'red heart', '😉': 'winking face'}, {'❤️': 'red heart'}, {'😘': 'face blowing a kiss', '❤️': 'red heart'}, {'🎂': 'birthday cake', '💘': 'heart with arrow', '📣': 'megaphone'}, {'♥': 'heart suit'}, {'♥': 'heart suit'}, {'😔': 'pensive face'}, {'♥': 'heart suit'}, {'❤️': 'red heart', '🌚': 'new moon face'}, {'🐶': 'dog face'}, {'👍': 'thumbs up', '🎉': 'party popper'}, {'💯': 'hundred points', '👌': 'OK hand', '✌️': 'victory hand'}, {'❤': 'red heart'}, {'👌': 'OK hand', '👍': 'thumbs up'}, {'😁': 'beaming face with smiling eyes'}, {'😂': 'face with tears of joy'}, {'😒': 'unamused face'}, {'❤️': 'red heart', '😄': 'grinning face with smiling eyes', '💜': 'purple heart'}, {'😔': 'pensive face'}, {'🎺': 'trumpet', '🎶': 'musical notes', '🎹': 'musical keyboard', '🎷': 'saxophone', '📯': 'postal horn', '🎵': 'musical note', '🎼': 'musical score', '🎸': 'guitar', '🎻': 'violin'}, {'👍': 'thumbs up'}, {'😉': 'winking face'}, {'🐶': 'dog face'}, {'👌': 'OK hand', '👆': 'backhand index pointing up', '✌️': 'victory hand'}, {'😂': 'face with tears of joy'}, {'💖': 'sparkling heart', '💙': 'blue heart', '💗': 'growing heart'}, {'😒': 'unamused face', '😭': 'loudly crying face'}, {'😁': 'beaming face with smiling eyes'}, {'♥': 'heart suit'}, {'☀️': 'sun', '💛': 'yellow heart', '😊': 'smiling face with smiling eyes'}, {'👍': 'thumbs up', '✌️': 'victory hand'}, {'💁': 'person tipping hand'}, {'🔫': 'water pistol', '😭': 'lou ...

# %%
all_keys = set().union(*(d.keys() for d in f))

# %%
print(all_keys)
# Out:
# {'✋', '👨\u200d👩\u200d👦\u200d👦', '🌚', '✊', '☺', '👰', '🔋', '😰', '😋', '🛒', '🚡', '💟', '💦', '⚡', '🐷', '🤐', '💙', '🤷\u200d♂️', '🔒', '🥩', '🙏🏼', '👬', '🇪🇸', '✒️', '🚽', '✊🏿', '🎅🏻', '💫', '👳', '😮', '👼', '®', '🌙', '📌', '🐺', '👗', '☣', '💰', '👨\u200d👩\u200d👧\u200d👧', '🆗', '♏', '💎', '🧘🏻\u200d♀️', '🐢', '🎇', '👇🏽', '🤧', '🤕', '🔕', '⏩', '🇫🇯', '🤦🏽\u200d♀️', '2️⃣', '👹', '🤩', '▪', '🙏🏿', '🍕', '🔓', '⬆', '⚪', '🍌', '🤘🏻', '📤', '🙋🏼\u200d♀️', '👯', '🌲', '📅', '🤚🏽', '⛈️', '🤭', '🌏', '☹️', '🏂', '😅', '🛀', '👐', '💁🏻\u200d♀️', '🌪', '🔷', '🤬', '🏋', '🔵', '😻', '🍳', '😺', '🚑', '🇧🇸', '☃', '⁉️', '👀', '👃', '🙏', '🙃', '☀', '🎣', '🤘', '💣', '💪🏼', '🤟🏽', '🍑', '🌾', '😶', '😷', '🐍', '🙌🏽', '👾', '😖', '🔌', '👸🏽', '🤫', '🐾', '🌧', '🍓', '🐸', '👱', '🤨', '🦀', '🏃\u200d♂️', '🤷\u200d♀️', '🍉', '➡️', '🍆', '🌱', '🌟', '🌵', '🗽', '✈️', '🕺', '🦅', '🔨', '🔮', '🐱', '🧛\u200d♂️', '🖖🏻', '🌞', '🎃', '⏱', '⭐', '💁', '🚷', '🎺', '💌', '♠️', '🎭', '🍹', '⛄', '🐐', '💅', '1️⃣', '🤙🏽', '💕', '📮', '🇸🇸', '☝️', '🌤', '🐙', '✔️', '🆓', '😨', '📸', '💁🏻\u200d♂️', '🎿', '✊🏾', '👌🏼', '🤦\u200d♂️', '❄', '🙏🏽', '🥵', '🐬', '🐑', '🔻', '📺', '🍛', '🍩', '🥪', '😚', '💐', '💆🏻\u200d♂', '🌳', '☺️', '👴', '😜', '🤦🏼\u200d♂️', '🚪', '🥓', '🕑', '⬆️', '⚫', '‼️', '🏵', '🌸', '👌🏿', '🤦🏽\u200d♂️', '💁\u200d♂️', '🤦🏼\u200d♀️', '🎑', '🕥', '💍', '✌🏽', '🚫', '😡', '🌶', '🍟', '💴', '🌊', '💆🏼\u200d♂️', '😁', '🌻', '🗣', '📊', '🚲', '🔜', '🌁', '🙅\u200d♂️', '📱', '⛸', '👏🏾', '👲', '🚴\u200d♂️', '🎉', '⛅', '🙅🏽\u200d♂️', '👏🏿', '🐨', '🎤', '🍂', '👆', '🏃', '🙉', '🅰', '🤦\u200d♀️', '☑', '🔚', '⛈', '🏎', '⛽', '👍🏼', '🍴', '💃', '⚖️', '😦', '🎸', '🔞', '😇', '😐', '🏰', '🌥', '🐏', '🙅🏾\u200d♂️', '💔', '🏏', '🐧', '📄', '👒', '👉🏽', '✏️', '🙆', '🍏', '🦂', '☠️', '™', '🌃', '😳', '🔰', '🎪', '🌝', '👉', '🐘', '👦🏻', '🙋🏻\u200d♀️', '😹', '🇦🇷', '👊🏼', '🏀', '🍅', '©', '😄', '✌️', '☠', '🆘', '🏄\u200d♂️', '🖕🏼', '🏆', '👧', '✈', '⏳', '🍰', '🍁', '🔊', '🐣', '☮', '👆🏽', '👈', '✂️', '🇬🇧', '🏜', '👏', '🍯', '🎥', '⤵', '😫', '💄', '🐀', '💡', '😏', '🗡️', '✊🏻', '🖕🏽', '❤', '💁🏼', '🌴', '👓', '💛', '🤷🏻\u200d♀️', '💊', '💈', '👽', '🌈', '🇮🇹', '😗', '❕', '🚶', '💪🏻', '📚', '🎵', '🚺', '✏', '🌄', '🙀', '🤔', '💞', '👫', '🚛', '🙌', '🍊', '🐔', '👨', '✝️', '🎬', '😆', '🤟🏻', '🍈', '🦋', '🚗', '📞', '👩🏼\u200d⚕️', '✌', '🥰', '🧟\u200d♂️', '💧', '🍵', '🌎', '🤡', '📹', '💨', '🚓', '🚴', '🥅', '😑', '🎷', '👂', '👠', '🤷🏾', '🗿', '😭', '🚊', '👼🏿', '☔', '🍬', '♐', '✋🏼', '💵', '🏥', '🤪', '☄', '🤷🏾\u200d♂️', '👮', '🎂', '🖐', '🎄', '🏊', '🐻', '☁', '🔔', '🍼', '😾', '👉🏿', '⚜️', '🐼', '🐚', '🇯🇵', '💥', '😧', '✴', '😊', '🙇', '🌯', '👌🏽', '❗', '🍎', '♿', '🥳', '🛏', '🤷🏼\u200d♀️', '📣', '😈', '🐽', '🌆', '🚨', '🍃', '🐶', '🤞', '💁🏽', '👊🏻', '🎨', '⛪', '🐛', '🚮', '✝', '😌', '🧐', '🧘🏽\u200d♀️', '🗑', '💏', '👦', '👚', '🕸', '🔦', '💜', '🌂', '🍇', '🌿', '🏒', '💶', '🍄', '💀', '🎈', '🐈', '🐮', '🐟', '💪', '📨', '👇🏼', '👍', '🛰', '🤷🏽\u200d♀️', '😛', '🏃🏼\u200d♀️', '👨\u200d👩\u200d👧\u200d👦', '💩', '🤗', '🌍', '🐉', '🤓', '⬇️', '☀️', '👈🏽', '😩', '💳', '🔄', '🎙️', '🍜', '👏🏼', '🕹️', '↩️', '☮️', '🍨', '🏴\U000e0067\U000e0062\U000e0065\U000e006e\U000e0067\U000e007f', '⚠', '😎', '⬇', '☕', '🐗', '👦🏿', '🤠', '🤙', '🍭', '😝', '👩', '🌬', '⚽', '👍🏻', '⬛', '🙌🏾', '♈', '🤢', '📖', '🔐', '🚍', '👼🏻', '💤', '📉', '🐂', '🎌', '🇺🇸', '🐳', '🖖🏽', '👄', '🍺', '❣', '⏲', '👌', '👏🏽', '📯', '🍖', '🤥', '😴', '🎅', '🐰', '🏽', '🍔', '🔬', '👟', '💚', '🤙🏻', '🚌', '🤦🏻\u200d♀️', '🖕', '📜', '👅', '📓', '😲', '📵', '🖤', '✨', '🔪', '👙', '😣', '🧠', '🏡', '🐜', '😒', '📥', '👻', '🙆\u200d♂️', '☹', '⚠️', '😤', '🇩🇪', '👿', '👋🏻', '🇪🇨', '👵', '💽', '🇪🇺', '🎯', '♥', '➖', '🎙', '🏦', '💉', '🐵', '🍝', '🍚', '📀', '🌨', '👍🏽', '👏🏻', '🏃\u200d♀️', '🐫', '👮\u200d♂️', '🏈', '♊', '😢', '🕷', '🍫', '📂', '▶', '💁🏽\u200d♀️', '✂', '🐴', '🔱', '😟', '💲', '📃', '💯', '🕰', '👸🏼', '🐅', '🎹', '🙋\u200d♀️', '🍀', '👆🏼', '🙊', '👣', '❄️', '🙁', '👉🏻', '🐯', '📆', '♥️', '😀', '💾', '🚼', '🐄', '🖖', '🅿️', '👔', '💖', '👨🏾\u200d💻', '🆙', '😠', '🌰', '🌅', '🛌', '💻', '🍒', '🙆🏻', '♉', '🐠', '👨🏻\u200d💻', '📶', '🇫🇷', '💅🏾', '🧡', '🙋', '💁🏼\u200d♂️', '📻', '😘', '🚂', '🔑', '🛋', '💷', '✅', '🛎', '🤑', '🦃', '👪', '🏹', '⭕', '💗', '👑', '🙌🏻', '👭', '⏰', '🏿', '🎎', '🥜', '🍋', '🐕', '⛵', '👌🏾', '⚰️', '💘', '◀️', '🙅', '😿', '🤷🏼\u200d♂️', '🤙🏼', '💁\u200d♀️', '🐇', '🦌', '🚙', '✍', '🎓', '🥬', '🔥', '🚐', '🔗', '🍗', '🌽', '😼', '🥃', '🐒', '🐊', '🚀', '✌🏾', '🎧', '🗯', '😥', '🏐', '💓', '🆕', '🤯', '⛷', '👍🏿', '👊', '🏇', '🇧🇪', '🌠', ' ...

# %%
len(all_keys)
# Out:
# 820

# %%
all_keys = list(all_keys)

# %%
from emoji import UNICODE_EMOJI

def get_emoji_set(text):
    return {letter for letter in text if letter in UNICODE_EMOJI['en'] }

# %%
c = get_emoji_set(emo_found)

# %%
print(c)
# Out:
# {'☁', '💦', '🎤', '🎅', '✨', '🏥', '😬', '😱', '❣', '😭', '😴', '🌍', '😅', '👏', '☕', '😁', '🕺', '🏿', '🤦', '😔', '💜', '📂', '✌', '❤', '🏾', '🖖', '😓', '💎', '🎂', '💯', '🌺', '💆', '🌹', '🐠', '😋', '🤪', '🍣', '😣', '😚', '♀', '👉', '📁', '💚', '✊', '😯', '▶', '👌', '😊', '😢', '💇', '📊', '🙁', '😂', '😖', '🐒', '💔', '😎', '🍻', '😃', '🔫', '🍕', '😥', '💣', '💙', '✔', '🐈', '🌏', '🔥', '💥', '🍊', '✝', '🔊', '💗', '📹', '🗽', '🎧', '🎶', '🌰', '🙍', '💈', '😑', '😞', '👦', '🏼', '💩', '🐸', '👊', '🍋', '😜', '😳', '😩', '💕', '🎵', '♊', '😛', '💀', '💃', '🍟', '😏', '😝', '⛽', '🎭', '🌸', '👫', '🤷', '🏽', '🌶', '🍀', '🏃', '⬛', '💪', '🎄', '😘', '🙀', '🔴', '🌟', '😲', '😈', '👆', '😍', '⚽', '🎈', '🎥', '⚠', '🍎', '🌄', '🍾', '💁', '😄', '🍁', '💖', '🎬', '👋', '🐚', '💊', '🌞', '🎪', '☮', '🌚', '💓', '😮', '❕', '👇', '🙄', '😨', '🕸', '👍', '✋', '😕', '😇', '😌', '🔪', '☀', '☃', '😼', '☠', '🍩', '👈', '⏳', '👼', '🏈', '📱', '🐥', '🅰', '😆', '😫', '🚫', '💐', '😡', '😉', '😀', '😒', '🎁', '🙏', '🍷', '🐾', '⭐', '♂', '🚽', '🐰', '🎼', '🔱', '🍃', '🎎', '🍔', '👑', '🤣', '❄', '☺', '🙌', '🌙', '🤨', '🏻', '🐱', '💋', '🐶', '👸', '👀', '🏆', '⁉', '🐟', '🌃', '🖼', '🙃', '🍹', '🤔', '😐', '🐨', '🍏', '🌻', '😧', '😹', '🐉', '🔻', '❌', '✅', '♥', '🌈'}

# %%
len(c)
# Out:
# 218

# %%
PRE_TRAINED_MODEL_NAME = 'bert-base-uncased'

# %%
tokenizer = BertTokenizer.from_pretrained(PRE_TRAINED_MODEL_NAME)
tokenizer.add_tokens(['✋', '👨\u200d👩\u200d👦\u200d👦', '🌚', '✊', '☺', '👰', '🔋', '😰', '😋', '🛒', '🚡', '💟', '💦', '⚡', '🐷', '🤐', '💙', '🤷\u200d♂️', '🔒', '🥩', '🙏🏼', '👬', '🇪🇸', '✒️', '🚽', '✊🏿', '🎅🏻', '💫', '👳', '😮', '👼', '®', '🌙', '📌', '🐺', '👗', '☣', '💰', '👨\u200d👩\u200d👧\u200d👧', '🆗', '♏', '💎', '🧘🏻\u200d♀️', '🐢', '🎇', '👇🏽', '🤧', '🤕', '🔕', '⏩', '🇫🇯', '🤦🏽\u200d♀️', '2️⃣', '👹', '🤩', '▪', '🙏🏿', '🍕', '🔓', '⬆', '⚪', '🍌', '🤘🏻', '📤', '🙋🏼\u200d♀️', '👯', '🌲', '📅', '🤚🏽', '⛈️', '🤭', '🌏', '☹️', '🏂', '😅', '🛀', '👐', '💁🏻\u200d♀️', '🌪', '🔷', '🤬', '🏋', '🔵', '😻', '🍳', '😺', '🚑', '🇧🇸', '☃', '⁉️', '👀', '👃', '🙏', '🙃', '☀', '🎣', '🤘', '💣', '💪🏼', '🤟🏽', '🍑', '🌾', '😶', '😷', '🐍', '🙌🏽', '👾', '😖', '🔌', '👸🏽', '🤫', '🐾', '🌧', '🍓', '🐸', '👱', '🤨', '🦀', '🏃\u200d♂️', '🤷\u200d♀️', '🍉', '➡️', '🍆', '🌱', '🌟', '🌵', '🗽', '✈️', '🕺', '🦅', '🔨', '🔮', '🐱', '🧛\u200d♂️', '🖖🏻', '🌞', '🎃', '⏱', '⭐', '💁', '🚷', '🎺', '💌', '♠️', '🎭', '🍹', '⛄', '🐐', '💅', '1️⃣', '🤙🏽', '💕', '📮', '🇸🇸', '☝️', '🌤', '🐙', '✔️', '🆓', '😨', '📸', '💁🏻\u200d♂️', '🎿', '✊🏾', '👌🏼', '🤦\u200d♂️', '❄', '🙏🏽', '🥵', '🐬', '🐑', '🔻', '📺', '🍛', '🍩', '🥪', '😚', '💐', '💆🏻\u200d♂', '🌳', '☺️', '👴', '😜', '🤦🏼\u200d♂️', '🚪', '🥓', '🕑', '⬆️', '⚫', '‼️', '🏵', '🌸', '👌🏿', '🤦🏽\u200d♂️', '💁\u200d♂️', '🤦🏼\u200d♀️', '🎑', '🕥', '💍', '✌🏽', '🚫', '😡', '🌶', '🍟', '💴', '🌊', '💆🏼\u200d♂️', '😁', '🌻', '🗣', '📊', '🚲', '🔜', '🌁', '🙅\u200d♂️', '📱', '⛸', '👏🏾', '👲', '🚴\u200d♂️', '🎉', '⛅', '🙅🏽\u200d♂️', '👏🏿', '🐨', '🎤', '🍂', '👆', '🏃', '🙉', '🅰', '🤦\u200d♀️', '☑', '🔚', '⛈', '🏎', '⛽', '👍🏼', '🍴', '💃', '⚖️', '😦', '🎸', '🔞', '😇', '😐', '🏰', '🌥', '🐏', '🙅🏾\u200d♂️', '💔', '🏏', '🐧', '📄', '👒', '👉🏽', '✏️', '🙆', '🍏', '🦂', '☠️', '™', '🌃', '😳', '🔰', '🎪', '🌝', '👉', '🐘', '👦🏻', '🙋🏻\u200d♀️', '😹', '🇦🇷', '👊🏼', '🏀', '🍅', '©', '😄', '✌️', '☠', '🆘', '🏄\u200d♂️', '🖕🏼', '🏆', '👧', '✈', '⏳', '🍰', '🍁', '🔊', '🐣', '☮', '👆🏽', '👈', '✂️', '🇬🇧', '🏜', '👏', '🍯', '🎥', '⤵', '😫', '💄', '🐀', '💡', '😏', '🗡️', '✊🏻', '🖕🏽', '❤', '💁🏼', '🌴', '👓', '💛', '🤷🏻\u200d♀️', '💊', '💈', '👽', '🌈', '🇮🇹', '😗', '❕', '🚶', '💪🏻', '📚', '🎵', '🚺', '✏', '🌄', '🙀', '🤔', '💞', '👫', '🚛', '🙌', '🍊', '🐔', '👨', '✝️', '🎬', '😆', '🤟🏻', '🍈', '🦋', '🚗', '📞', '👩🏼\u200d⚕️', '✌', '🥰', '🧟\u200d♂️', '💧', '🍵', '🌎', '🤡', '📹', '💨', '🚓', '🚴', '🥅', '😑', '🎷', '👂', '👠', '🤷🏾', '🗿', '😭', '🚊', '👼🏿', '☔', '🍬', '♐', '✋🏼', '💵', '🏥', '🤪', '☄', '🤷🏾\u200d♂️', '👮', '🎂', '🖐', '🎄', '🏊', '🐻', '☁', '🔔', '🍼', '😾', '👉🏿', '⚜️', '🐼', '🐚', '🇯🇵', '💥', '😧', '✴', '😊', '🙇', '🌯', '👌🏽', '❗', '🍎', '♿', '🥳', '🛏', '🤷🏼\u200d♀️', '📣', '😈', '🐽', '🌆', '🚨', '🍃', '🐶', '🤞', '💁🏽', '👊🏻', '🎨', '⛪', '🐛', '🚮', '✝', '😌', '🧐', '🧘🏽\u200d♀️', '🗑', '💏', '👦', '👚', '🕸', '🔦', '💜', '🌂', '🍇', '🌿', '🏒', '💶', '🍄', '💀', '🎈', '🐈', '🐮', '🐟', '💪', '📨', '👇🏼', '👍', '🛰', '🤷🏽\u200d♀️', '😛', '🏃🏼\u200d♀️', '👨\u200d👩\u200d👧\u200d👦', '💩', '🤗', '🌍', '🐉', '🤓', '⬇️', '☀️', '👈🏽', '😩', '💳', '🔄', '🎙️', '🍜', '👏🏼', '🕹️', '↩️', '☮️', '🍨', '🏴\U000e0067\U000e0062\U000e0065\U000e006e\U000e0067\U000e007f', '⚠', '😎', '⬇', '☕', '🐗', '👦🏿', '🤠', '🤙', '🍭', '😝', '👩', '🌬', '⚽', '👍🏻', '⬛', '🙌🏾', '♈', '🤢', '📖', '🔐', '🚍', '👼🏻', '💤', '📉', '🐂', '🎌', '🇺🇸', '🐳', '🖖🏽', '👄', '🍺', '❣', '⏲', '👌', '👏🏽', '📯', '🍖', '🤥', '😴', '🎅', '🐰', '🏽', '🍔', '🔬', '👟', '💚', '🤙🏻', '🚌', '🤦🏻\u200d♀️', '🖕', '📜', '👅', '📓', '😲', '📵', '🖤', '✨', '🔪', '👙', '😣', '🧠', '🏡', '🐜', '😒', '📥', '👻', '🙆\u200d♂️', '☹', '⚠️', '😤', '🇩🇪', '👿', '👋🏻', '🇪🇨', '👵', '💽', '🇪🇺', '🎯', '♥', '➖', '🎙', '🏦', '💉', '🐵', '🍝', '🍚', '📀', '🌨', '👍🏽', '👏🏻', '🏃\u200d♀️', '🐫', '👮\u200d♂️', '🏈', '♊', '😢', '🕷', '🍫', '📂', '▶', '💁🏽\u200d♀️', '✂', '🐴', '🔱', '😟', '💲', '📃', '💯', '🕰', '👸🏼', '🐅', '🎹', '🙋\u200d♀️', '🍀', '👆🏼', '🙊', '👣', '❄️', '🙁', '👉🏻', '🐯', '📆', '♥️', '😀', '💾', '🚼', '🐄', '🖖', '🅿️', '👔', '💖', '👨🏾\u200d💻', '🆙', '😠', '🌰', '🌅', '🛌', '💻', '🍒', '🙆🏻', '♉', '🐠', '👨🏻\u200d💻', '📶', '🇫🇷', '💅🏾', '🧡', '🙋', '💁🏼\u200d♂️', '📻', '😘', '🚂', '🔑', '🛋', '💷', '✅', '🛎', '🤑', '🦃', '👪', '🏹', '⭕', '💗', '👑', '🙌🏻', '👭', '⏰', '🏿', '🎎', '🥜', '🍋', '🐕', '⛵', '👌🏾', '⚰️', '💘', '◀️', '🙅', '😿', '🤷🏼\u200d♂️', '🤙🏼', '💁\u200d♀️', '🐇', '🦌', '🚙', '✍', '🎓', '🥬', '🔥', '🚐', '🔗', '🍗', '🌽', '😼', '🥃', '🐒', '🐊', '🚀', '✌🏾', '🎧', '🗯', '😥', '🏐', '💓', '🆕', '🤯', '⛷', '👍🏿', '👊', '🏇', '🇧🇪', '🌠', '😽', '🚔', '🏃🏽', '💆🏻\u200d♂️', '🐥', '👎🏻', '🎶', '📝', '😬', '🎼', '🙍', '📍', '🎆', '👼🏽', '👋', '😃', '💇🏾\u200d♀️', '🙎', '🍿', '👎', '👇🏻', '👇', '💪🏽', '🐁', '❎', '👌🏻', '🦄', '📈', '🎁', '☁️', '😸', '☝🏽', '😞', '🙋🏻\u200d♂️', '🙂', '😪', '❓', '⏺️', '🌼', '🖼', '🇮🇳', '♦', '💢', '😔', '🌀', '❤️', '🍥', '🚎', '🍦', '🚣', '👶', '📷', '😱', '💭', '🍣', '🌋', '😯', '🤷🏿\u200d♀️', '💸', '🖊', '🐿', '🍪', '⚾', '✌🏼', '➰', '🍍', '☝', '🙅🏻', '🔫', '🎻', '🙌🏼', '👍🏾', '💁🏻\u200d♂', '🤤', '⚓', '✌🏻', '⁉', '🈵', '🔉', '🍡', '🕐', '💋', '😵', '😕', '👸🏻', '🤦🏽', '🌺', '👎🏼', '🚜', '🍧', '⚒️', '❌', '🤦🏻\u200d♂️', '🙄', '🆒', '🥇', '🥂', '🍻', '🎊', '🏢', '0⃣', '3️⃣', '🔴', '🤣', '🔝', '🌌', '✔', '🚘', '🍤', '📁', '😂', '🍸', '🎀', '💝', '🤮', '🎮', '🏁', '🌮', '✖', '🤦', '🚢', '🌹', '😙', '👸', '😍', '🇩🇰', '👴🏻', '😓', '🤟🏾', '☂', '😉', '🍷', '💑', '🍾', '➡', '🚬', '👺', '🇨🇦', '🙈'])
# Out:
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# 814

# %%
df_train_X= list(df_train["Tweet"])
df_val_X = list(df_val["Tweet"])

# %%
y_train = list(df_train["Label"])

y_val = list(df_val["Label"])

y_test = list(df_test["Label"])

# %%
X_train_tokenized = tokenizer(df_train_X, padding=True, truncation=True, max_length=512)
X_val_tokenized = tokenizer(df_val_X, padding=True, truncation=True, max_length=512)

# %%
class Dataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels=None):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item["labels"] = torch.tensor([self.labels[idx]])
        return item

    def __len__(self):
        return len(self.encodings["input_ids"])

# %%
train_dataset = Dataset(X_train_tokenized, y_train)
val_dataset = Dataset(X_val_tokenized, y_val)

# %%
model = BertForSequenceClassification.from_pretrained(
    "bert-base-uncased", # Use the 12-layer BERT model, with an uncased vocab.
    num_labels = 2, # The number of output labels--2 for binary classification.
                    # You can increase this for multi-class tasks.   
    output_attentions = False, # Whether the model returns attentions weights.
    output_hidden_states = False, # Whether the model returns all hidden-states.
)

model.resize_token_embeddings(len(tokenizer))
# Out:
# Downloading:   0%|          | 0.00/420M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Embedding(31336, 768)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
model.to(device)
# Out:
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(31336, 768)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=768, out_features=2, bias=True)
# )

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score

def compute_metrics(p):
    pred, labels = p
    pred = np.argmax(pred, axis=1)

    accuracy = accuracy_score(y_true=labels, y_pred=pred)
    recall = recall_score(y_true=labels, y_pred=pred)
    precision = precision_score(y_true=labels, y_pred=pred)
    f1 = f1_score(y_true=labels, y_pred=pred)

    return {"accuracy": accuracy, "precision": precision, "recall": recall, "f1": f1}

# %%
output_dir='./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek'

# %%
import wandb

# %%
from transformers import TrainingArguments, Trainer

args = TrainingArguments(
    output_dir=output_dir,
    evaluation_strategy="steps",
    weight_decay = 0.01,
    logging_steps = 500,
    eval_steps = 500,
    logging_dir='./logs/arch1_run3_ptacek',
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    num_train_epochs=4,
    seed=123,
    load_best_model_at_end=True,
    #save_total_limit=1,
    learning_rate = 2e-5
)

# %%
from transformers import EarlyStoppingCallback

trainer = Trainer(
    model=model,                         # the instantiated 🤗 Transformers model to be trained
    args= args,                  # training arguments, defined above
    train_dataset=train_dataset,         # training dataset
    eval_dataset=val_dataset,             # evaluation dataset
    tokenizer = tokenizer,
    compute_metrics = compute_metrics,
    callbacks=[EarlyStoppingCallback(early_stopping_patience=20)]
)

trainer.train()
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 102157
#   Num Epochs = 4
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 51080
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# wandb: Currently logged in as: nazmus007. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.12.17
# Run data is saved locally in <code>/content/wandb/run-20220609_175518-3rtfew98</code>
# Syncing run <strong><a href="https://wandb.ai/nazmus007/huggingface/runs/3rtfew98" target="_blank">./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek</a></strong> to <a href="https://wandb.ai/nazmus007/huggingface" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
#     <div>
#
#       <progress value='21500' max='51080' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [21500/51080 2:14:18 < 3:04:48, 2.67 it/s, Epoch 1/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.598000</td>
#       <td>0.361874</td>
#       <td>0.828287</td>
#       <td>0.641812</td>
#       <td>0.484503</td>
#       <td>0.552172</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.521500</td>
#       <td>0.370412</td>
#       <td>0.824862</td>
#       <td>0.606176</td>
#       <td>0.566441</td>
#       <td>0.585635</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.508700</td>
#       <td>0.341429</td>
#       <td>0.848758</td>
#       <td>0.716216</td>
#       <td>0.509797</td>
#       <td>0.595630</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.479600</td>
#       <td>0.326272</td>
#       <td>0.851639</td>
#       <td>0.685773</td>
#       <td>0.592447</td>
#       <td>0.635703</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.459800</td>
#       <td>0.333154</td>
#       <td>0.852495</td>
#       <td>0.706148</td>
#       <td>0.556466</td>
#       <td>0.622435</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.447500</td>
#       <td>0.331423</td>
#       <td>0.849226</td>
#       <td>0.783572</td>
#       <td>0.428215</td>
#       <td>0.553789</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.462900</td>
#       <td>0.321255</td>
#       <td>0.858488</td>
#       <td>0.734027</td>
#       <td>0.552547</td>
#       <td>0.630488</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.428900</td>
#       <td>0.318433</td>
#       <td>0.866661</td>
#       <td>0.726033</td>
#       <td>0.625935</td>
#       <td>0.672279</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.438900</td>
#       <td>0.321180</td>
#       <td>0.859967</td>
#       <td>0.703390</td>
#       <td>0.620948</td>
#       <td>0.659603</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.429400</td>
#       <td>0.333231</td>
#       <td>0.862380</td>
#       <td>0.775305</td>
#       <td>0.521197</td>
#       <td>0.623349</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.421300</td>
#       <td>0.326926</td>
#       <td>0.860979</td>
#       <td>0.752348</td>
#       <td>0.542216</td>
#       <td>0.630228</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.417900</td>
#       <td>0.319789</td>
#       <td>0.857554</td>
#       <td>0.698658</td>
#       <td>0.612041</td>
#       <td>0.652488</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>0.413400</td>
#       <td>0.375277</td>
#       <td>0.869619</td>
#       <td>0.771854</td>
#       <td>0.572497</td>
#       <td>0.657394</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.424500</td>
#       <td>0.303386</td>
#       <td>0.866272</td>
#       <td>0.749885</td>
#       <td>0.582116</td>
#       <td>0.655435</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>0.404800</td>
#       <td>0.348957</td>
#       <td>0.855375</td>
#       <td>0.660793</td>
#       <td>0.694692</td>
#       <td>0.677319</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.411200</td>
#       <td>0.310400</td>
#       <td>0.865650</td>
#       <td>0.742921</td>
#       <td>0.588885</td>
#       <td>0.656995</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>0.410700</td>
#       <td>0.310888</td>
#       <td>0.862770</td>
#       <td>0.672733</td>
#       <td>0.724261</td>
#       <td>0.697547</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.418800</td>
#       <td>0.297571</td>
#       <td>0.872422</td>
#       <td>0.739541</td>
#       <td>0.642323</td>
#       <td>0.687512</td>
#     </tr>
#     <tr>
#       <td>9500</td>
#       <td>0.394900</td>
#       <td>0.341138</td>
#       <td>0.870009</td>
#       <td>0.770585</td>
#       <td>0.576772</td>
#       <td>0.659739</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.400100</td>
#       <td>0.304654</td>
#       <td>0.869697</td>
#       <td>0.699824</td>
#       <td>0.706804</td>
#       <td>0.703297</td>
#     </tr>
#     <tr>
#       <td>10500</td>
#       <td>0.381500</td>
#       <td>0.299315</td>
#       <td>0.872188</td>
#       <td>0.706927</td>
#       <td>0.708942</td>
#       <td>0.707933</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>0.388400</td>
#       <td>0.288117</td>
#       <td>0.877481</td>
#       <td>0.736660</td>
#       <td>0.683648</td>
#       <td>0.709165</td>
#     </tr>
#     <tr>
#       <td>11500</td>
#       <td>0.402500</td>
#       <td>0.286839</td>
#       <td>0.875068</td>
#       <td>0.729389</td>
#       <td>0.680798</td>
#       <td>0.704256</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>0.395300</td>
#       <td>0.297165</td>
#       <td>0.874290</td>
#       <td>0.760490</td>
#       <td>0.619879</td>
#       <td>0.683023</td>
#     </tr>
#     <tr>
#       <td>12500</td>
#       <td>0.401400</td>
#       <td>0.313968</td>
#       <td>0.874445</td>
#       <td>0.750000</td>
#       <td>0.638048</td>
#       <td>0.689509</td>
#     </tr>
#     <tr>
#       <td>13000</td>
#       <td>0.348800</td>
#       <td>0.383277</td>
#       <td>0.872188</td>
#       <td>0.704171</td>
#       <td>0.715711</td>
#       <td>0.709894</td>
#     </tr>
#     <tr>
#       <td>13500</td>
#       <td>0.317700</td>
#       <td>0.335723</td>
#       <td>0.874056</td>
#       <td>0.708670</td>
#       <td>0.719273</td>
#       <td>0.713932</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>0.291900</td>
#       <td>0.414303</td>
#       <td>0.870553</td>
#       <td>0.707547</td>
#       <td>0.694692</td>
#       <td>0.701061</td>
#     </tr>
#     <tr>
#       <td>14500</td>
#       <td>0.315200</td>
#       <td>0.370968</td>
#       <td>0.864715</td>
#       <td>0.717542</td>
#       <td>0.628073</td>
#       <td>0.669833</td>
#     </tr>
#     <tr>
#       <td>15000</td>
#       <td>0.309400</td>
#       <td>0.380722</td>
#       <td>0.879349</td>
#       <td>0.754763</td>
#       <td>0.663342</td>
#       <td>0.706105</td>
#     </tr>
#     <tr>
#       <td>15500</td>
#       <td>0.315500</td>
#       <td>0.327766</td>
#       <td>0.871098</td>
#       <td>0.684751</td>
#       <td>0.759886</td>
#       <td>0.720365</td>
#     </tr>
#     <tr>
#       <td>16000</td>
#       <td>0.299700</td>
#       <td>0.425280</td>
#       <td>0.873745</td>
#       <td>0.724177</td>
#       <td>0.681867</td>
#       <td>0.702385</td>
#     </tr>
#     <tr>
#       <td>16500</td>
#       <td>0.312100</td>
#       <td>0.385061</td>
#       <td>0.873978</td>
#       <td>0.699597</td>
#       <td>0.741717</td>
#       <td>0.720042</td>
#     </tr>
#     <tr>
#       <td>17000</td>
#       <td>0.309500</td>
#       <td>0.379660</td>
#       <td>0.869931</td>
#       <td>0.701991</td>
#       <td>0.703242</td>
#       <td>0.702616</td>
#     </tr>
#     <tr>
#       <td>17500</td>
#       <td>0.327400</td>
#       <td>0.331698</td>
#       <td>0.871721</td>
#       <td>0.693878</td>
#       <td>0.738867</td>
#       <td>0.715666</td>
#     </tr>
#     <tr>
#       <td>18000</td>
#       <td>0.307800</td>
#       <td>0.410328</td>
#       <td>0.873278</td>
#       <td>0.727168</td>
#       <td>0.672248</td>
#       <td>0.698630</td>
#     </tr>
#     <tr>
#       <td>18500</td>
#       <td>0.314000</td>
#       <td>0.408511</td>
#       <td>0.870320</td>
#       <td>0.707379</td>
#       <td>0.693267</td>
#       <td>0.700252</td>
#     </tr>
#     <tr>
#       <td>19000</td>
#       <td>0.320600</td>
#       <td>0.344727</td>
#       <td>0.877170</td>
#       <td>0.741834</td>
#       <td>0.671535</td>
#       <td>0.704936</td>
#     </tr>
#     <tr>
#       <td>19500</td>
#       <td>0.311700</td>
#       <td>0.399294</td>
#       <td>0.862925</td>
#       <td>0.660135</td>
#       <td>0.768080</td>
#       <td>0.710028</td>
#     </tr>
#     <tr>
#       <td>20000</td>
#       <td>0.319200</td>
#       <td>0.382514</td>
#       <td>0.878571</td>
#       <td>0.732910</td>
#       <td>0.698967</td>
#       <td>0.715536</td>
#     </tr>
#     <tr>
#       <td>20500</td>
#       <td>0.301300</td>
#       <td>0.420188</td>
#       <td>0.875847</td>
#       <td>0.763708</td>
#       <td>0.625223</td>
#       <td>0.687561</td>
# ***** Running Evaluation *****
#   Num examples = 12847
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-500
# Configuration saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-500/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-500/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-500/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-500/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-500/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 12847
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-1000
# Configuration saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-1000/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-1000/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-1000/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-1000/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-1000/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 12847
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-1500
# Configuration saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-1500/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-1500/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-1500/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-1500/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-1500/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 12847
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-2000
# Configuration saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-2000/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-2000/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-2000/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-2000/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-2000/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 12847
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-2500
# Configuration saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-2500/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-2500/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-2500/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-2500/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-2500/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 12847
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-3000
# Configuration saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-3000/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-3000/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-3000/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-3000/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-3000/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 12847
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-3500
# Configuration saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-3500/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-3500/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-3500/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-3500/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-3500/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 12847
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-4000
# Configuration saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-4000/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-4000/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-4000/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-4000/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-4000/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 12847
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-4500
# Configuration saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-4500/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-4500/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-4500/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-4500/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-4500/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 12847
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-5000
# Configuration saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-5000/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-5000/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-5000/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-5000/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-5000/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 12847
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-5500
# Configuration saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-5500/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-5500/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-5500/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-5500/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-5500/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 12847
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-6000
# Configuration saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-6000/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-6000/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-6000/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-6000/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-6000/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 12847
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-6500
# Configuration saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-6500/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-6500/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-6500/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-6500/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-6500/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 12847
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-7000
# Configuration saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-7000/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-7000/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-7000/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-7000/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-7000/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 12847
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-7500
# Configuration saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-7500/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-7500/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-7500/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-7500/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-7500/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 12847
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-8000
# Configuration saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-8000/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-8000/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-8000/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-8000/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-8000/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 12847
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-8500
# Configuration saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-8500/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-8500/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-8500/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-8500/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-8500/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 12847
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-9000
# Configuration saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-9000/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-9000/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-9000/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-9000/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-9000/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 12847
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-9500
# Configuration saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-9500/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-9500/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-9500/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-9500/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-9500/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 12847
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-10000
# Configuration saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-10000/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-10000/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-10000/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-10000/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-10000/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 12847
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-10500
# Configuration saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-10500/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-10500/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-10500/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-10500/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-10500/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 12847
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-11000
# Configuration saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-11000/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-11000/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-11000/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-11000/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-11000/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 12847
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-11500
# Configuration saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-11500/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-11500/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-11500/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-11500/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-11500/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 12847
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-12000
# Configuration saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-12000/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-12000/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-12000/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-12000/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-12000/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 12847
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-12500
# Configuration saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-12500/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-12500/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-12500/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-12500/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-12500/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 12847
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-13000
# Configuration saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-13000/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-13000/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-13000/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-13000/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-13000/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 12847
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-13500
# Configuration saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-13500/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-13500/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-13500/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-13500/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-13500/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 12847
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-14000
# Configuration saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-14000/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-14000/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-14000/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-14000/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-14000/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 12847
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-14500
# Configuration saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-14500/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-14500/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-14500/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-14500/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-14500/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 12847
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-15000
# Configuration saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-15000/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-15000/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-15000/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-15000/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-15000/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 12847
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-15500
# Configuration saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-15500/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-15500/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-15500/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-15500/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-15500/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 12847
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-16000
# Configuration saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-16000/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-16000/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-16000/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-16000/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-16000/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 12847
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-16500
# Configuration saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-16500/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-16500/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-16500/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-16500/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-16500/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 12847
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-17000
# Configuration saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-17000/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-17000/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-17000/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-17000/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-17000/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 12847
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-17500
# Configuration saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-17500/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-17500/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-17500/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-17500/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-17500/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 12847
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-18000
# Configuration saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-18000/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-18000/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-18000/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-18000/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-18000/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 12847
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-18500
# Configuration saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-18500/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-18500/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-18500/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-18500/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-18500/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 12847
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-19000
# Configuration saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-19000/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-19000/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-19000/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-19000/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-19000/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 12847
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-19500
# Configuration saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-19500/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-19500/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-19500/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-19500/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-19500/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 12847
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-20000
# Configuration saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-20000/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-20000/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-20000/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-20000/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-20000/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 12847
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-20500
# Configuration saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-20500/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-20500/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-20500/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-20500/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-20500/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 12847
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-21000
# Configuration saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-21000/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-21000/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-21000/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-21000/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-21000/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 12847
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-21500
# Configuration saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-21500/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-21500/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-21500/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-21500/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-21500/added_tokens.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from ./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-11500 (score: 0.28683850169181824).
# TrainOutput(global_step=21500, training_loss=0.38425476641987644, metrics={'train_runtime': 8071.9423, 'train_samples_per_second': 50.623, 'train_steps_per_second': 6.328, 'total_flos': 2.846071977495852e+16, 'train_loss': 0.38425476641987644, 'epoch': 1.68})

# %%
#test_data = pd.read_csv("test.csv")
X_test = list(df_test["Tweet"])
X_test_tokenized = tokenizer(X_test, padding=True, truncation=True, max_length=512)

# Create torch dataset
test_dataset = Dataset(X_test_tokenized,y_test)

# Load trained model
model_path = "./drive/MyDrive/savedmodel_meta/arch1_final_shayan_ptacek/checkpoint-11500"

model = BertForSequenceClassification.from_pretrained(model_path, num_labels=2)

# Define test trainer
test_trainer = Trainer(model)

# Make prediction
raw_pred, _, _ = test_trainer.predict(test_dataset)

# Preprocess raw predictions
y_pred = np.argmax(raw_pred, axis=1)
# Out:
# ***** Running Prediction *****
#   Num examples = 12847
#   Batch size = 8
#     <div>
#
#       <progress value='1606' max='1606' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1606/1606 00:31]
#     </div>

# %%
from sklearn.metrics import confusion_matrix, classification_report
print(classification_report(y_test, y_pred,labels=[1,0]))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.73      0.69      0.71      2990
#            0       0.91      0.92      0.92      9857
#
#     accuracy                           0.87     12847
#    macro avg       0.82      0.81      0.81     12847
# weighted avg       0.87      0.87      0.87     12847

# %%
class_names = [1,0]

# %%
def show_confusion_matrix(confusion_matrix):
  hmap = sns.heatmap(confusion_matrix, annot=True, fmt="d", cmap="Blues")
  hmap.yaxis.set_ticklabels(hmap.yaxis.get_ticklabels(), rotation=0, ha='right')
  hmap.xaxis.set_ticklabels(hmap.xaxis.get_ticklabels(), rotation=30, ha='right')
  plt.ylabel('True sentiment')
  plt.xlabel('Predicted sentiment');

cm = confusion_matrix(y_test, y_pred)
df_cm = pd.DataFrame(cm, index=class_names, columns=class_names)
show_confusion_matrix(df_cm)
